# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-36.62698086757488, 0.23665332377646564), (15.255513063224157, -4.64257232007202), (53.936747768576794, -118.38287083654524), (78.60850592117507, -17.41223471320606), (74.7567387101212, -37.27366425265373), (79.23581551183457, -84.53740169812538), (-27.40914110613698, -32.04092063722385), (1.0856526765875145, -106.51090225394417), (69.075053611074, -148.82499037839185), (34.84126816370838, -70.97553362272335), (68.87617520817042, -109.05834253424644), (-50.42162243171485, 178.4745020873604), (21.6083920230505, -179.61347404897785), (-4.777399808657535, -73.29585833333113), (71.50377965897317, -73.67464008299969), (-39.223760064643564, -92.33640322707953), (-57.96708111053968, -71.87476922643246), (61.43073119154408, -43.09777917111782), (-50.85570799479076, 162.306236808052), (-19.928020068924553, -37.712830338646455), (34.25162826094885, -100.98788888240443), (-35.391220784556694, -90.51388333961262), (-50.26267001882172, -68.21375693351554), (-67.08750155584143, -56.87970579033055), (56.13337454167416, 96.09881072509359), (-13.447906696067335, -106.09155893672133), (82.4530841933786, -20.286931029232505), (-16.38111572857322, 52.23553296691071), (-19.415234785646135, 48.11990145811981), (61.28009569301926, 0.0663334049233697), (72.76036820162085, -87.43526851782384), (44.99819899626823, -71.40523991232936), (-79.9696551494317, -45.103436561643264), (-66.75267254404112, 80.0369138046616), (-14.225540663843162, -1.5418303216031006), (69.71554248983335, 109.58868885073582), (29.22711485402631, 17.349428343320255), (50.76674882313844, 14.267054851099175), (-55.319628335238974, 112.45945871920736), (-63.047263611807324, 97.9373670880455), (-52.04752974372445, -85.04858172420806), (82.37962238350838, 22.075761385010026), (-83.64451166086579, -161.84809714680088), (41.29794236035943, 83.81804012298994), (52.96136112481312, -1.5681983879838697), (0.7283335687243522, -59.66495064492608), (87.80731836979967, 134.3409799212946), (-77.62068803721563, -132.6312146711977), (8.521200444184515, -86.26325251889925), (16.49352684679816, 123.01753526342691), (39.35653871259984, 129.8364939511228), (-57.61684978744159, -25.59454771171127), (-40.90814897716879, -13.101987527959409), (38.071652224675205, 66.97037107323945), (-66.86946438768778, 122.13867474116847), (-84.73225195794973, 85.92415492473333), (89.79522434705487, 90.12536143377895), (4.002186226163843, -82.55575908739957), (-45.448706208190664, -127.15027707447007), (-47.07742524556252, -11.284531131489217), (-24.37288832842026, -69.79031261094255), (44.77910257488827, -3.9383376401637804), (-26.863253794932255, -15.196922417004401), (43.17941649028455, -73.65694246785743), (-22.556896924019327, 31.26719704608408), (-5.716927252302511, -110.52774829558884), (86.50653494411546, -160.35397102904423), (39.61051172012043, -98.29799996142594), (13.942935781114187, 43.63397695267156), (-73.60080993160284, 170.5937843670759), (47.31767521557262, 60.090797675881845), (6.081629769757029, -171.11876528655588), (-30.942078239621914, -0.7045800333256125), (33.875527049127896, -111.3768685442826), (74.84527337755827, -178.20300015563245), (-80.52097448998265, -151.59816878871123), (-72.55945966520791, -68.79266945832477), (-85.04443961353816, 86.40813102637941), (-78.41180942976557, -146.83662442131936), (-18.364636342476174, 90.93474142734595), (-1.1358129003710644, 9.729091661446091), (-81.61656139982824, 84.47626433713594), (-88.97965229983328, 108.814275253701), (-59.36143312930244, -61.48064668263402), (-81.49462134085968, -121.3583967767282), (-61.368754274314824, -152.16137301994397), (71.62816673403228, 76.25562267021797), (-77.98514247819793, 96.00620651946593), (-72.15013855026861, 151.69018970315256), (-12.097981047353045, -141.14105256289724), (88.2693437141682, -110.85576837762977), (-8.673227091371672, 67.51275896573625), (44.52292722239022, -150.00751362129452), (54.271729314579744, -172.64799837527192), (-83.87285480543628, 43.355039712582226), (-58.84263178391182, -90.1671073510 ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 720

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        cloudiness = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        weather_description=city_weather["weather"][0]["description"]

        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append(
            {"City": city,
             "Lat": lat,
             "Lng": lng,
             "Max Temp": max_temp,
             "Humidity": humidity,
             "Cloudiness": cloudiness,
             "Wind Speed": wind,
             "Country": country,
             "Current Description": weather_description
            })
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | tenenkou
# Processing Record 3 of Set 1 | hinton
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | sao joao da barra
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | virginia beach
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | christchurch
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | saquena
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | tuatapere
# Processing Record 20 of Set 1 | linhares
# Processing Record 21 of Set 1 | plainview
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | rio gallegos
# Processing Record 24 of Set 1 | ilanskiy
# Processing Record 25 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 1 | moramanga
# Processing Record 27 of Set 1 | lerwick
# Processing Record 28 of Set 1 | coaticook
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | aykhal
# Processing Record 32 of Set 1 | waddan
# Processing Record 33 of Set 1 | benesov nad ploucnici
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 1 | derby
# Processing Record 40 of Set 1 | boa vista
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | nicoya
# Processing Record 44 of Set 1 | dicabisagan
# Processing Record 45 of Set 1 | khasan
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | boysun
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | la palma
# Processing Record 50 of Set 1 | antofagasta
# Processing Record 1 of Set 2 | santander
# Processing Record 2 of Set 2 | glens falls
# Processing Record 3 of Set 2 | thohoyandou
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | hastings
# Processing Record 6 of Set 2 | zabid
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | emba
# Processing Record 9 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 2 | payson
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | omboue
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | hendrina
# Processing Record 21 of Set 2 | ostrovnoy
# Processing Record 22 of Set 2 | itoman
# Processing Record 23 of Set 2 | alyangula
# Processing Record 24 of Set 2 | ambulu
# Processing Record 25 of Set 2 | saint anthony
# Processing Record 26 of Set 2 | show low
# Processing Record 27 of Set 2 | batemans bay
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | atasu
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | xiaoweizhai
# Processing Record 36 of Set 2 | mount isa
# Processing Record 37 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | zaraza
# Processing Record 40 of Set 2 | hambantota
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | douglas
# Processing Record 43 of Set 2 | abu samrah
# Processing Record 44 of Set 2 | mosquera
# Processing Record 45 of Set 2 | pringsewu
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | west helena
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | dingle
# Processing Record 1 of Set 3 | okha
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | saint-ambroise
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 3 | itamaraca
# Processing Record 11 of Set 3 | veraval
# Processing Record 12 of Set 3 | lazo
# Processing Record 13 of Set 3 | vizinga
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | osa
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | szydlowiec
# Processing Record 18 of Set 3 | temerloh
# Processing Record 19 of Set 3 | orange park
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | camacha
# Processing Record 22 of Set 3 | touros
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | fortuna
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | kushmurun
# Processing Record 28 of Set 3 | santa cruz de la palma
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 3 | vilyuysk
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | akyab
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | quelimane
# Processing Record 37 of Set 3 | half moon bay
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | mamallapuram
# Processing Record 40 of Set 3 | anjangaon
# Processing Record 41 of Set 3 | cabedelo
# Processing Record 42 of Set 3 | springfield
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | luena
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | tilichiki
# Processing Record 48 of Set 3 | teneguiban
# City not found. Skipping...
# Processing Record 49 of Set 3 | saldanha
# Processing Record 50 of Set 3 | puerto baquerizo moreno
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | campbellton
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | coahuayana
# Processing Record 6 of Set 4 | deer lake
# Processing Record 7 of Set 4 | libreville
# Processing Record 8 of Set 4 | havelock
# Processing Record 9 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 4 | sinnamary
# Processing Record 11 of Set 4 | vila do maio
# Processing Record 12 of Set 4 | leo
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | wanning
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | saint-honore
# Processing Record 17 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 4 | mitu
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | kloulklubed
# Processing Record 21 of Set 4 | qujing
# Processing Record 22 of Set 4 | turukhansk
# Processing Record 23 of Set 4 | alexandria
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | tambura
# Processing Record 26 of Set 4 | buta
# Processing Record 27 of Set 4 | omsukchan
# Processing Record 28 of Set 4 | aripuana
# Processing Record 29 of Set 4 | znamenskoye
# Processing Record 30 of Set 4 | sant julia de loria
# Processing Record 31 of Set 4 | jaguaruna
# Processing Record 32 of Set 4 | moose factory
# Processing Record 33 of Set 4 | biltine
# Processing Record 34 of Set 4 | kununurra
# Processing Record 35 of Set 4 | lagoa
# Processing Record 36 of Set 4 | antalaha
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | qaqortoq
# Processing Record 39 of Set 4 | ongandjera
# Processing Record 40 of Set 4 | gat
# Processing Record 41 of Set 4 | custodia
# Processing Record 42 of Set 4 | butaritari
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | tuktoyaktuk
# Processing Record 45 of Set 4 | taltal
# Processing Record 46 of Set 4 | takestan
# Processing Record 47 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | tessalit
# Processing Record 2 of Set 5 | valparaiso
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | rosarito
# Processing Record 6 of Set 5 | lasa
# Processing Record 7 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 5 | betafo
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | isangel
# Processing Record 12 of Set 5 | rio casca
# Processing Record 13 of Set 5 | namatanai
# Processing Record 14 of Set 5 | pemangkat
# Processing Record 15 of Set 5 | osvaldo cruz
# Processing Record 16 of Set 5 | makakilo city
# Processing Record 17 of Set 5 | sao raimundo das mangabeiras
# Processing Record 18 of Set 5 | orange cove
# Processing Record 19 of Set 5 | vestmannaeyjar
# Processing Record 20 of Set 5 | aquiraz
# Processing Record 21 of Set 5 | hit
# Processing Record 22 of Set 5 | bathsheba
# Processing Record 23 of Set 5 | monte santo
# Processing Record 24 of Set 5 | puerto carreno
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | puttur
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | puerto suarez
# Processing Record 29 of Set 5 | plettenberg bay
# Processing Record 30 of Set 5 | leningradskiy
# Processing Record 31 of Set 5 | bousse
# Processing Record 32 of Set 5 | flin flon
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | nouadhibou
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | mildura
# Processing Record 38 of Set 5 | karangampel
# Processing Record 39 of Set 5 | peniche
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | coquimbo
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | snyder
# Processing Record 44 of Set 5 | bluefields
# Processing Record 45 of Set 5 | la ronge
# Processing Record 46 of Set 5 | poronaysk
# Processing Record 47 of Set 5 | saint-joseph
# Processing Record 48 of Set 5 | vallenar
# Processing Record 49 of Set 5 | te anau
# Processing Record 50 of Set 5 | ahipara
# Processing Record 1 of Set 6 | manakara
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | russell
# Processing Record 4 of Set 6 | san juan
# Processing Record 5 of Set 6 | praia
# Processing Record 6 of Set 6 | alvorada
# Processing Record 7 of Set 6 | yulara
# Processing Record 8 of Set 6 | vanimo
# Processing Record 9 of Set 6 | mehamn
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 6 | truth or consequences
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | nemuro
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 6 | laurel
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | bonnyville
# Processing Record 20 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 6 | akure
# Processing Record 22 of Set 6 | paita
# Processing Record 23 of Set 6 | guerrero negro
# Processing Record 24 of Set 6 | rundu
# Processing Record 25 of Set 6 | carutapera
# Processing Record 26 of Set 6 | cuamba
# Processing Record 27 of Set 6 | panjab
# Processing Record 28 of Set 6 | horsham
# Processing Record 29 of Set 6 | talakan
# Processing Record 30 of Set 6 | waitati
# Processing Record 31 of Set 6 | rabo de peixe
# Processing Record 32 of Set 6 | carson city
# Processing Record 33 of Set 6 | airai
# Processing Record 34 of Set 6 | saskylakh
# Processing Record 35 of Set 6 | talara
# Processing Record 36 of Set 6 | mahon
# Processing Record 37 of Set 6 | zheleznodorozhnyy
# Processing Record 38 of Set 6 | carnarvon
# Processing Record 39 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 6 | lashio
# Processing Record 41 of Set 6 | holland
# Processing Record 42 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | puerto del rosario
# Processing Record 45 of Set 6 | zhigansk
# Processing Record 46 of Set 6 | ligayan
# Processing Record 47 of Set 6 | nago
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | general roca
# Processing Record 50 of Set 6 | haines junction
# Processing Record 1 of Set 7 | broome
# Processing Record 2 of Set 7 | ruyigi
# Processing Record 3 of Set 7 | praia da vitoria
# Processing Record 4 of Set 7 | novosheshminsk
# Processing Record 5 of Set 7 | husavik
# Processing Record 6 of Set 7 | san jose
# Processing Record 7 of Set 7 | malanje
# Processing Record 8 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 7 | pochutla
# Processing Record 10 of Set 7 | donskoye
# Processing Record 11 of Set 7 | san quintin
# Processing Record 12 of Set 7 | yazman
# Processing Record 13 of Set 7 | west bay
# Processing Record 14 of Set 7 | chavakkad
# Processing Record 15 of Set 7 | yenagoa
# Processing Record 16 of Set 7 | capao bonito
# Processing Record 17 of Set 7 | yar-sale
# Processing Record 18 of Set 7 | ulagan
# Processing Record 19 of Set 7 | hillsborough
# Processing Record 20 of Set 7 | roebourne
# Processing Record 21 of Set 7 | ribeira grande
# Processing Record 22 of Set 7 | ketchikan
# Processing Record 23 of Set 7 | warrnambool
# Processing Record 24 of Set 7 | newcastle
# Processing Record 25 of Set 7 | nola
# Processing Record 26 of Set 7 | tuensang
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | buraydah
# Processing Record 29 of Set 7 | palu
# Processing Record 30 of Set 7 | oconomowoc
# Processing Record 31 of Set 7 | smithers
# Processing Record 32 of Set 7 | wodonga
# Processing Record 33 of Set 7 | kibakwe
# Processing Record 34 of Set 7 | hasaki
# Processing Record 35 of Set 7 | asfi
# Processing Record 36 of Set 7 | srednekolymsk
# Processing Record 37 of Set 7 | taraclia
# Processing Record 38 of Set 7 | cacoal
# Processing Record 39 of Set 7 | havoysund
# Processing Record 40 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 7 | batagay-alyta
# Processing Record 42 of Set 7 | fernie
# Processing Record 43 of Set 7 | lorengau
# Processing Record 44 of Set 7 | svetlogorsk
# Processing Record 45 of Set 7 | port lincoln
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | motril
# Processing Record 48 of Set 7 | paidha
# Processing Record 49 of Set 7 | narsaq
# Processing Record 50 of Set 7 | mackenzie
# Processing Record 1 of Set 8 | weligama
# Processing Record 2 of Set 8 | cockburn town
# Processing Record 3 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 8 | jiazi
# Processing Record 5 of Set 8 | orlik
# Processing Record 6 of Set 8 | marmaron
# City not found. Skipping...
# Processing Record 7 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | tonj
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | chontalpa
# Processing Record 12 of Set 8 | san carlos
# Processing Record 13 of Set 8 | verkh-suetka
# Processing Record 14 of Set 8 | broken hill
# Processing Record 15 of Set 8 | togur
# Processing Record 16 of Set 8 | norman wells
# Processing Record 17 of Set 8 | sorland
# Processing Record 18 of Set 8 | manokwari
# Processing Record 19 of Set 8 | flinders
# Processing Record 20 of Set 8 | labuhan
# Processing Record 21 of Set 8 | bilma
# Processing Record 22 of Set 8 | djambala
# Processing Record 23 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 24 of Set 8 | preobrazheniye
# Processing Record 25 of Set 8 | nyurba
# Processing Record 26 of Set 8 | grand-santi
# Processing Record 27 of Set 8 | southbridge
# Processing Record 28 of Set 8 | cidreira
# Processing Record 29 of Set 8 | balod
# Processing Record 30 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 8 | gladstone
# Processing Record 32 of Set 8 | elati
# Processing Record 33 of Set 8 | verkhoyansk
# Processing Record 34 of Set 8 | banda aceh
# Processing Record 35 of Set 8 | san miguel
# Processing Record 36 of Set 8 | coihaique
# Processing Record 37 of Set 8 | sosua
# Processing Record 38 of Set 8 | colchester
# Processing Record 39 of Set 8 | san francisco
# Processing Record 40 of Set 8 | namibe
# Processing Record 41 of Set 8 | wagar
# Processing Record 42 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 8 | brigantine
# Processing Record 44 of Set 8 | rosetta
# Processing Record 45 of Set 8 | honiara
# Processing Record 46 of Set 8 | portland
# Processing Record 47 of Set 8 | manacor
# Processing Record 48 of Set 8 | labrea
# Processing Record 49 of Set 8 | belmonte
# Processing Record 50 of Set 8 | abalak
# Processing Record 1 of Set 9 | the pas
# Processing Record 2 of Set 9 | kimbe
# Processing Record 3 of Set 9 | manta
# Processing Record 4 of Set 9 | fengzhen
# Processing Record 5 of Set 9 | padang
# Processing Record 6 of Set 9 | rapid valley
# Processing Record 7 of Set 9 | bull savanna
# Processing Record 8 of Set 9 | lompoc
# Processing Record 9 of Set 9 | oum hadjer
# Processing Record 10 of Set 9 | bambanglipuro
# Processing Record 11 of Set 9 | kahului
# Processing Record 12 of Set 9 | amapa
# Processing Record 13 of Set 9 | bac can
# City not found. Skipping...
# Processing Record 14 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 9 | quatre cocos
# Processing Record 16 of Set 9 | san patricio
# Processing Record 17 of Set 9 | cherskiy
# Processing Record 18 of Set 9 | talcahuano
# Processing Record 19 of Set 9 | clarksburg
# Processing Record 20 of Set 9 | waipawa
# Processing Record 21 of Set 9 | coihueco
# Processing Record 22 of Set 9 | sao jose da coroa grande
# Processing Record 23 of Set 9 | mulege
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | nantucket
# Processing Record 26 of Set 9 | yarmouth
# Processing Record 27 of Set 9 | tacuarembo
# Processing Record 28 of Set 9 | ghanzi
# Processing Record 29 of Set 9 | berezniki
# Processing Record 30 of Set 9 | makokou
# Processing Record 31 of Set 9 | rensvik
# Processing Record 32 of Set 9 | kobelyaky
# Processing Record 33 of Set 9 | erzurum
# Processing Record 34 of Set 9 | ossora
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | koungou
# Processing Record 37 of Set 9 | samarai
# Processing Record 38 of Set 9 | kingman
# Processing Record 39 of Set 9 | maniago
# Processing Record 40 of Set 9 | yarada
# Processing Record 41 of Set 9 | kenai
# Processing Record 42 of Set 9 | edd
# Processing Record 43 of Set 9 | tiarei
# Processing Record 44 of Set 9 | lao cai
# Processing Record 45 of Set 9 | graaff-reinet
# Processing Record 46 of Set 9 | axim
# Processing Record 47 of Set 9 | chippewa falls
# Processing Record 48 of Set 9 | huilong
# Processing Record 49 of Set 9 | kinsale
# Processing Record 50 of Set 9 | panzhihua
# Processing Record 1 of Set 10 | ixtapa
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | salalah
# Processing Record 4 of Set 10 | port hardy
# Processing Record 5 of Set 10 | melbu
# Processing Record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 10 | asau
# Processing Record 9 of Set 10 | beringovskiy
# Processing Record 10 of Set 10 | berlevag
# Processing Record 11 of Set 10 | udachnyy
# Processing Record 12 of Set 10 | muisne
# Processing Record 13 of Set 10 | skegness
# Processing Record 14 of Set 10 | bataysk
# Processing Record 15 of Set 10 | ulverstone
# Processing Record 16 of Set 10 | santa catarina de tepehuanes
# Processing Record 17 of Set 10 | solnechnyy
# Processing Record 18 of Set 10 | santa maria
# Processing Record 19 of Set 10 | candelaria
# Processing Record 20 of Set 10 | tarko-sale
# Processing Record 21 of Set 10 | iquique
# Processing Record 22 of Set 10 | olinda
# Processing Record 23 of Set 10 | gizo
# Processing Record 24 of Set 10 | gornopravdinsk
# Processing Record 25 of Set 10 | chitral
# Processing Record 26 of Set 10 | marsa matruh
# Processing Record 27 of Set 10 | freeport
# Processing Record 28 of Set 10 | mogadishu
# Processing Record 29 of Set 10 | barda
# Processing Record 30 of Set 10 | manukan
# Processing Record 31 of Set 10 | canguaretama
# Processing Record 32 of Set 10 | kriel
# Processing Record 33 of Set 10 | muros
# Processing Record 34 of Set 10 | khani
# Processing Record 35 of Set 10 | afyonkarahisar
# Processing Record 36 of Set 10 | tocopilla
# Processing Record 37 of Set 10 | umm kaddadah
# Processing Record 38 of Set 10 | henties bay
# Processing Record 39 of Set 10 | taoudenni
# Processing Record 40 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 10 | kerman
# Processing Record 42 of Set 10 | angoche
# Processing Record 43 of Set 10 | alakurtti
# Processing Record 44 of Set 10 | fortuna foothills
# Processing Record 45 of Set 10 | kovernino
# Processing Record 46 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 47 of Set 10 | kaohsiung
# Processing Record 48 of Set 10 | macusani
# Processing Record 49 of Set 10 | jackson
# Processing Record 50 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 11 | korla
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | sao felix do xingu
# Processing Record 4 of Set 11 | miyako
# Processing Record 5 of Set 11 | senanga
# Processing Record 6 of Set 11 | bantry
# Processing Record 7 of Set 11 | uribia
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | hovd
# Processing Record 10 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 11 | tiksi
# Processing Record 12 of Set 11 | yumen
# Processing Record 13 of Set 11 | umm lajj
# Processing Record 14 of Set 11 | souillac
# Processing Record 15 of Set 11 | gimli
# Processing Record 16 of Set 11 | chopovychi
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | mombetsu
# Processing Record 19 of Set 11 | lander
# Processing Record 20 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 11 | mizan teferi
# Processing Record 22 of Set 11 | narrabri
# Processing Record 23 of Set 11 | deputatskiy
# Processing Record 24 of Set 11 | puerto madero
# Processing Record 25 of Set 11 | haizhou
# Processing Record 26 of Set 11 | teya
# Processing Record 27 of Set 11 | san jeronimo
# Processing Record 28 of Set 11 | faya
# Processing Record 29 of Set 11 | hanmer springs
# Processing Record 30 of Set 11 | ayorou
# Processing Record 31 of Set 11 | itapaci
# Processing Record 32 of Set 11 | bac lieu
# Processing Record 33 of Set 11 | mosetse
# Processing Record 34 of Set 11 | adrar
# Processing Record 35 of Set 11 | kaitangata
# Processing Record 36 of Set 11 | bandar-e lengeh
# Processing Record 37 of Set 11 | yangambi
# Processing Record 38 of Set 11 | aklavik
# Processing Record 39 of Set 11 | shingu
# Processing Record 40 of Set 11 | ust-uda
# Processing Record 41 of Set 11 | ambilobe
# Processing Record 42 of Set 11 | kongoussi
# Processing Record 43 of Set 11 | bibiani
# Processing Record 44 of Set 11 | terme
# Processing Record 45 of Set 11 | valentin gomez farias
# Processing Record 46 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 47 of Set 11 | hami
# Processing Record 48 of Set 11 | salvador
# Processing Record 49 of Set 11 | puerto colombia
# Processing Record 50 of Set 11 | puerto narino
# Processing Record 1 of Set 12 | mari-turek
# Processing Record 2 of Set 12 | bakaly
# Processing Record 3 of Set 12 | eureka
# Processing Record 4 of Set 12 | heze
# Processing Record 5 of Set 12 | abu dhabi
# Processing Record 6 of Set 12 | riverton
# Processing Record 7 of Set 12 | waingapu
# Processing Record 8 of Set 12 | plouzane
# Processing Record 9 of Set 12 | rio grande
# Processing Record 10 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 12 | brae
# Processing Record 12 of Set 12 | catalina
# Processing Record 13 of Set 12 | shenzhen
# Processing Record 14 of Set 12 | maniitsoq
# Processing Record 15 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 12 | imeni poliny osipenko
# Processing Record 17 of Set 12 | turayf
# Processing Record 18 of Set 12 | abnub
# Processing Record 19 of Set 12 | ust-nera
# Processing Record 20 of Set 12 | mayo
# Processing Record 21 of Set 12 | villazon
# Processing Record 22 of Set 12 | peachland
# Processing Record 23 of Set 12 | constantine
# Processing Record 24 of Set 12 | upata
# Processing Record 25 of Set 12 | kollo
# Processing Record 26 of Set 12 | pyay
# Processing Record 27 of Set 12 | necochea
# Processing Record 28 of Set 12 | dwarka
# Processing Record 29 of Set 12 | bubaque
# Processing Record 30 of Set 12 | marrakesh
# Processing Record 31 of Set 12 | tchollire
# Processing Record 32 of Set 12 | elat
# Processing Record 33 of Set 12 | yurya
# City not found. Skipping...
# Processing Record 34 of Set 12 | banjar
# Processing Record 35 of Set 12 | weingarten
# Processing Record 36 of Set 12 | port augusta
# Processing Record 37 of Set 12 | tezu
# Processing Record 38 of Set 12 | vostok
# Processing Record 39 of Set 12 | pandan
# Processing Record 40 of Set 12 | trairi
# Processing Record 41 of Set 12 | hualmay
# Processing Record 42 of Set 12 | kyzyl-suu
# Processing Record 43 of Set 12 | dashitou
# Processing Record 44 of Set 12 | innisfail
# Processing Record 45 of Set 12 | san cristobal
# Processing Record 46 of Set 12 | wad rawah
# Processing Record 47 of Set 12 | nakhon thai
# Processing Record 48 of Set 12 | kibala
# Processing Record 49 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 12 | kushima
# Processing Record 1 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 2 of Set 13 | snezhnogorsk
# Processing Record 3 of Set 13 | benguela
# Processing Record 4 of Set 13 | ji-parana
# City not found. Skipping...
# Processing Record 5 of Set 13 | chapleau
# Processing Record 6 of Set 13 | osoyoos
# Processing Record 7 of Set 13 | guarapuava
# Processing Record 8 of Set 13 | seymchan
# Processing Record 9 of Set 13 | alto araguaia
# Processing Record 10 of Set 13 | naze
# Processing Record 11 of Set 13 | bowen
# Processing Record 12 of Set 13 | livramento
# Processing Record 13 of Set 13 | sandovo
# Processing Record 14 of Set 13 | balkhash
# Processing Record 15 of Set 13 | dukat
# Processing Record 16 of Set 13 | scottsbluff
# Processing Record 17 of Set 13 | bozova
# Processing Record 18 of Set 13 | ikryanoye
# Processing Record 19 of Set 13 | sangar
# Processing Record 20 of Set 13 | oranjemund
# Processing Record 21 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 22 of Set 13 | matamoros
# Processing Record 23 of Set 13 | boone
# Processing Record 24 of Set 13 | skjervoy
# Processing Record 25 of Set 13 | anavra
# Processing Record 26 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 13 | pitiquito
# Processing Record 29 of Set 13 | fukue
# Processing Record 30 of Set 13 | oriximina
# Processing Record 31 of Set 13 | baglan
# Processing Record 32 of Set 13 | kalmunai
# Processing Record 33 of Set 13 | urumqi
# Processing Record 34 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 13 | salinopolis
# Processing Record 36 of Set 13 | los llanos de aridane
# Processing Record 37 of Set 13 | kalabo
# Processing Record 38 of Set 13 | noumea
# Processing Record 39 of Set 13 | bo phloi
# Processing Record 40 of Set 13 | sladkovo
# Processing Record 41 of Set 13 | burgeo
# Processing Record 42 of Set 13 | todos santos
# Processing Record 43 of Set 13 | porto novo
# Processing Record 44 of Set 13 | whitecourt
# Processing Record 45 of Set 13 | great falls
# Processing Record 46 of Set 13 | nandu
# Processing Record 47 of Set 13 | goundam
# Processing Record 48 of Set 13 | raton
# Processing Record 49 of Set 13 | nelson bay
# Processing Record 50 of Set 13 | santa luzia
# Processing Record 1 of Set 14 | devils lake
# Processing Record 2 of Set 14 | tovarkovskiy
# Processing Record 3 of Set 14 | duobao
# Processing Record 4 of Set 14 | san joaquin
# Processing Record 5 of Set 14 | barreirinha
# Processing Record 6 of Set 14 | bam
# Processing Record 7 of Set 14 | waw
# Processing Record 8 of Set 14 | nangomba
# Processing Record 9 of Set 14 | canandaigua
# Processing Record 10 of Set 14 | tazovskiy
# Processing Record 11 of Set 14 | vestmanna
# Processing Record 12 of Set 14 | kourou
# Processing Record 13 of Set 14 | ulaangom
# Processing Record 14 of Set 14 | celestun
# Processing Record 15 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 14 | carmarthen
# Processing Record 17 of Set 14 | hamilton
# Processing Record 18 of Set 14 | cleveland
# Processing Record 19 of Set 14 | gondanglegi
# Processing Record 20 of Set 14 | bure
# Processing Record 21 of Set 14 | haapiti
# Processing Record 22 of Set 14 | sibolga
# Processing Record 23 of Set 14 | arkhipo-osipovka
# Processing Record 24 of Set 14 | novyy urengoy
# Processing Record 25 of Set 14 | grand gaube
# Processing Record 26 of Set 14 | bundaberg
# Processing Record 27 of Set 14 | cadiz
# Processing Record 28 of Set 14 | tura
# Processing Record 29 of Set 14 | eyl
# Processing Record 30 of Set 14 | sungaipenuh
# Processing Record 31 of Set 14 | pangoa
# Processing Record 32 of Set 14 | carthage
# Processing Record 33 of Set 14 | kindia
# Processing Record 34 of Set 14 | neyvo-rudyanka
# Processing Record 35 of Set 14 | hay river
# Processing Record 36 of Set 14 | zeya
# Processing Record 37 of Set 14 | viedma
# Processing Record 38 of Set 14 | liaozhong
# Processing Record 39 of Set 14 | chino valley
# Processing Record 40 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 14 | binga
# Processing Record 42 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 14 | rancho palos verdes
# Processing Record 44 of Set 14 | neuquen
# Processing Record 45 of Set 14 | corner brook
# Processing Record 46 of Set 14 | sokyryany
# Processing Record 47 of Set 14 | shubarshi
# Processing Record 48 of Set 14 | harper
# Processing Record 49 of Set 14 | blythe
# Processing Record 50 of Set 14 | amantea
# Processing Record 1 of Set 15 | maine-soroa
# Processing Record 2 of Set 15 | esna
# Processing Record 3 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 15 | teruel
# Processing Record 5 of Set 15 | mamou
# Processing Record 6 of Set 15 | haukipudas
# Processing Record 7 of Set 15 | terra santa
# Processing Record 8 of Set 15 | soure
# Processing Record 9 of Set 15 | vardo
# Processing Record 10 of Set 15 | stokmarknes
# Processing Record 11 of Set 15 | hobyo
# Processing Record 12 of Set 15 | imelda
# Processing Record 13 of Set 15 | abha
# Processing Record 14 of Set 15 | lagos
# Processing Record 15 of Set 15 | meulaboh
# Processing Record 16 of Set 15 | kopervik
# Processing Record 17 of Set 15 | thanh hoa
# Processing Record 18 of Set 15 | pisco
# Processing Record 19 of Set 15 | monrovia
# Processing Record 20 of Set 15 | yeehaw junction
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 659

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           luderitz -26.6481   15.1594     64.87        81           4
# 1           tenenkou  14.4572   -4.9169     69.26        15          11
# 2             hinton  53.4001 -117.5857     30.51        88          67
# 3           tasiilaq  65.6145  -37.6368      4.05        84          57
# 4            qaanaaq  77.4840  -69.3632    -20.29        71          12
# 5  sao joao da barra -21.6403  -41.0511     80.69        87          61
# 6       puerto ayora  -0.7393  -90.3518     78.76        87          95
# 7            college  64.8569 -147.8028     10.58        86          86
# 8     virginia beach  36.8529  -75.9780     71.64        70         100
# 9        yellowknife  62.4560 -114.3525      5.56        92         100
#
#    Wind Speed Country Current Description
# 0       14.97      NA           clear sky
# 1        9.66      ML          few clouds
# 2        3.76      CA       broken clouds
# 3        5.55      GL       broken clouds
# 4        2.73      GL          few clouds
# 5       20.87      BR       broken clouds
# 6        4.00      EC     overcast clouds
# 7        2.98      US     overcast clouds
# 8       12.66      US     overcast clouds
# 9       10.36      CA          light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_columns]

# Display sample data
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     luderitz      NA -26.6481   15.1594     64.87        81           4
# 1     tenenkou      ML  14.4572   -4.9169     69.26        15          11
# 2       hinton      CA  53.4001 -117.5857     30.51        88          67
# 3     tasiilaq      GL  65.6145  -37.6368      4.05        84          57
# 4      qaanaaq      GL  77.4840  -69.3632    -20.29        71          12
# ..         ...     ...      ...       ...       ...       ...         ...
# 654   meulaboh      ID   4.1363   96.1285     75.02        90         100
# 655   kopervik      NO  59.2835    5.3067     43.32        75          75
# 656  thanh hoa      VN  19.8000  105.7667     61.11        64         100
# 657      pisco      PE -13.7000  -76.2167     71.65        78           0
# 658   monrovia      LR   6.3005  -10.7969     78.76        79           3
#
#      Wind Speed Current Description
# 0         14.97           clear sky
# 1          9.66          few clouds
# 2          3.76       broken clouds
# 3          5.55       broken clouds
# 4          2.73          few clouds
# ..          ...                 ...
# 654        3.06     overcast clouds
# 655       20.71             drizzle
# 656        1.43     overcast clouds
# 657       19.57           clear sky
# 658        7.20           clear sky
#
# [659 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "/Users/nataliebernal/Desktop/git/Challenge/Weather_Database_Challenge/Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City ID")
